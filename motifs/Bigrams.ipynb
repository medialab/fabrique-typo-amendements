# %%
import re
import csv
import math
import spacy
import pandas as pd
from spacy.symbols import nsubj, nsubjpass, dobj, iobj, pobj
from collections import Counter, defaultdict
from itertools import islice
from html2text import html2text
from fog.tokenizers import ngrams
from tqdm import tqdm_notebook

# %%
nlp = spacy.load('fr')

# %%
DATA = '../amds_vectors.csv'
STOPWORDS = './stopwords.txt'
BIGRAMS = './bigrams.csv'
LABELS = set([nsubj, nsubjpass, dobj, iobj, pobj])

# %%
WHITESPACE_RE = re.compile(r'\n+')
AMENDEMENTS = []
with open(DATA, 'r') as f:
    reader = csv.DictReader(f)
    
    for line in reader:
        line['expose'] = WHITESPACE_RE.sub(' ', html2text(line['expose']))
        AMENDEMENTS.append(line)

# %%
STOPWORDS_SET = set()

with open(STOPWORDS, 'r') as f:
    for line in f.readlines():
        line = line.strip()
        
        if line:
            STOPWORDS_SET.add(line)

# %%
BIGRAMS_SET = {}

with open(BIGRAMS, 'r') as f:
    reader = csv.DictReader(f)
    
    for line in reader:
        if line['Class'] == 'drop' or not line['Class']:
            continue
        BIGRAMS_SET[(line['A'], line['B'])] = line['Class']

# %%
set(category for category in BIGRAMS_SET.values())
# Out:
# {'actor', 'institution', 'intention', 'support', 'thel', 'theme', 'type'}

# %%
pd.DataFrame(AMENDEMENTS).head(100)
# Out:
#                                                expose nb_signataires  \
# 0   Le présent amendement demande au gouvernement ...              2
# 1   Cet amendement vise à simplifier les obligatio...             14
# 2   Les centres de formation d'apprentis jouent un...             15
# 3   Les partenaires sociaux avaient déjà lancé, lo...              1
# 4   La formulation exposée dans le présent texte «...              3
# 5   Cet amendement vise à combler une lacune du pr...             17
# 6   La loi du 17 août 2015 n'a pas gagné le pari d...             14
# 7   La loi n° 2016‑1657 du 5 décembre 2016 relativ...             14
# 8                                                                 14
# 9   Afin de garantir le suivi des candidatures et ...              3
# 10  Cet amendement vise à garantir l'équilibre des...              5
# 11  L'article crée notamment une nouvelle commissi...              1
# 12  Selon nous, rien ne justifie ni la méthode, ni...              1
# 13  Cet amendement vise à préciser le seuil minima...              1
# 14  Il y a lieu de caractériser, de manière plus p...              1
# 15  Cet amendement a pour objectif d'apporter une ...              1
# 16  Selon nous, rien ne justifie ni la méthode, ni...             17
# 17  Cet amendement de précision rappelle qu'en auc...             14
# 18  Cet amendement vise à permettre la réalisation...              1
# 19  Cet article élargit les possibilités de réquis...              6
# 20  Cet amendement vise à supprimer une dispositio...              1
# 21  L'amendement vise à compléter la nature des au...              1
# 22  Porté par l'Association nationale des élus de ...              1
# 23  Cet amendement est un amendement de repli. L'é...             32
# 24  Pour gérer le projet de transition professionn...              1
# 25  L'avis rendu par la commission départementale ...              1
# 26  Il s'agit d'une attaque à l'encontre de la loi...              1
# 27  La compétence en matière de politique de l'hab...             30
# 28  Inspiré de l'avis du Conseil d'État, cet amend...              5
# 29  La possibilité laissée au bailleur de dissocie...             32
# ..                                                ...            ...
# 70  Par cet amendement, afin de lutter contre les ...             17
# 71  Ce sous-amendement vise à préciser quels types...             41
# 72  L'extension du champ de l'accord majoritaire, ...              1
# 73  Selon toute évidence, la modification des règl...             13
# 74  Le présent amendement vise à supprimer la poss...             16
# 75  L'alinéa 3 de l'article 4 de la présente propo...              4
# 76  Si le SCoT a un rôle majeur dans la déclinaiso...              1
# 77  Le présent amendement vise à tenir compte des ...             22
# 78  Le prélèvement à la source ne présente aujourd...              1
# 79  La loi de finances pour 2016 a créé un fonds d...              3
# 80  Par cet amendement, nous proposons d'élargir l...             17
# 81  L'alinéa a) du 3° de l'article 3 vise à diminu...             17
# 82  Par cet amendement, nous proposons d'élargir l...             17
# 83  Le présent amendement vise à supprimer la poss...             16
# 84  L'objectif du présent amendement est de permet...              1
# 85  Selon nous, rien ne justifie ni la méthode, ni...             16
# 86  Les territoires populaires situés en zone tend...             30
# 87  Selon nous, rien ne justifie ni la méthode, ni...             17
# 88  Ce sous-amendement vise à préciser l'obligatio...             41
# 89                          Amendement de précision.               1
# 90  Les ordonnances souhaitent étendre de manière ...             13
# 91  En vertu de l'article L. 424‑5 du Code de l'ur...             25
# 92  Cet amendement de précision a pour objet de pr...             14
# 93  La proposition de loi étant relative à la lutt...              1
# 94  Sans revenir sur les dispositions et l'esprit ...             17
# 95  La proposition de loi étant relative à la lutt...              1
# 96  L'égal accès de l'ensemble des publics à la qu...              1
# 97  Cet amendement précise la portée de la disposi...             10
# 98  Le Gouvernement propose de reporter d'1 an la ...              2
# 99  Le présent amendement vise à garantir la capac...              1
#
#                      groupes expose_ln duplicates  \
# 0                       LREM       587          1
# 1                         LR      1132          1
# 2                       LREM       644          1
# 3                         LR      1720          1
# 4                         LR       229          1
# 5                         LR       169          2
# 6                         LR       264          1
# 7   GDR,LR,LREM,MODEM,NG,UAI      4124          1
# 8                         LR         0          1
# 9                       LREM       484          1
# 10                        LR       181          1
# 11                      LREM       597          1
# 12                       LFI       266          1
# 13                        LC       809          1
# 14                        LC       293          1
# 15                      LREM       579          1
# 16                       LFI       266          1
# 17                        LR       160          3
# 18                        LR      3062          1
# 19                        NI       640          1
# 20              gouvernement      1074          3
# 21                      LREM       611          1
# 22                      LREM      1542          2
# 23                       UAI       817          2
# 24              gouvernement       671          1
# 25                     MODEM       399          1
# 26                        NI       277          5
# 27                        NG      2347          1
# 28                        NG       863          1
# 29                       UAI       842          1
# ..                       ...       ...        ...
# 70                       LFI      1409          1
# 71                      LREM      1614          1
# 72                        LR       892          1
# 73                        LR       226          1
# 74                       GDR      1030          3
# 75                        NG      1100          4
# 76              gouvernement      1466          1
# 77                        LR       432          1
# 78                        LR       481          2
# 79                      LREM      1379          1
# 80                       LFI      1549          1
# 81                       LFI       764          1
# 82                       LFI      1535          1
# 83                       GDR      1477          1
# 84              gouvernement       552          1
# 85                       LFI       266          1
# 86                        NG       901          1
# 87                       LFI       266          2
# 88                      LREM       484          1
# 89                      LREM        32          1
# 90                        LR      1154          1
# 91                        LR      3511          2
# 92                        LR       231          3
# 93                      LREM       335          1
# 94                      LREM      2614          1
# 95                      LREM       335          1
# 96                      LREM       322          1
# 97                      LREM       535          3
# 98                        NG      1204          2
# 99                      LREM      4676          1
#
#                                           signataires                 sort  \
# 0                               M. Sommer, M. Barbier               Retiré
# 1   M. Hetzel,  M. Marleix, M. Straumann, M. Quent...               Retiré
# 15  <p>I. – À l'avant-dernier alinéa de l'article ...
# 16                       <p>Supprimer l'alinéa 5.</p>
# 17  <p>Après l'alinéa 7, insérer l'alinéa suivant ...
# 18  <p>Le livre Ier du code de l'urbanisme est ain...
# 19                      <p>Supprimer cet article.</p>
# 20                      <p>Supprimer cet article.</p>
# 21  <p>Compléter l'alinéa 2 par les mots :</p><p>«...
# 22  <p>L'article L. 151‑15 du code de l'urbanisme ...
# 23  <p>À l'alinéa 2, substituer aux mots :</p><p>«...
# 24  <p>Après l'alinéa 32, insérer l'alinéa suivant...
# 25  <p>À la première phrase de l'alinéa 2, après l...
# 26                      <p>Supprimer cet article.</p>
# 27  <p>Compléter cet article par l'alinéa suivant ...
# 28  <p>À l'alinéa 2, substituer au mot :</p><p>« n...
# 29  <p>L'article L. 442‑6‑4 du code de la construc...
# ..                                                ...
# 70  <p>I. – Après l'alinéa 1, insérer les deux ali...
# 71  <p>À  l'avant-dernier alinéa, après le mot :</...
# 72  <p>À l'alinéa 13, après le mot :</p><p>« salar...
# 73  <p>Rédiger ainsi le début de l'alinéa 2 :</p><...
# 74  <p>À la première phrase de l'alinéa 2, supprim...
# 75  <p>À la première phrase de l'alinéa 3, suppri...
# 76  <p>À la première phrase de l'alinéa 7, après l...
# 77  <p>Après la première phrase de l'alinéa 2, ins...
# 78  <p>À l'alinéa 1, substituer aux mots :</p><p>«...
# 79  <p>Après l'alinéa 40, insérer l'alinéa suivant...
# 80  <p>À la première phrase de l'alinéa 3, substit...
# 81  <p>Compléter l'alinéa 12 par les mots :</p><p>...
# 82  <p>À l'alinéa 3, après le mots:</p><p>« Nation...
# 83  <p>Supprimer la seconde phrase de l'alinéa 2.</p>
# 84  <p>I. – Compléter l'alinéa 23 par la phrase su...
# 85                      <p>Supprimer cet article.</p>
# 86  <p>Après l'alinéa 3, insérer les deux alinéas ...
# 87                   <p>Retiré avant publication.</p>
# 88  <p>Compléter l'avant-dernier alinéa par la phr...
# 89  <p>I. – Compléter l'alinéa 46 par les mots :</...
# 90  <p>Compléter l'alinéa 12 par les mots :</p><p>...
# 91  <p>L'article L. 424‑5 du code de l'urbanisme e...
# 92  <p>Compléter l'alinéa 3 par la phrase suivante...
# 93  <p>À l'alinéa 2, supprimer le mot :</p><p>« , ...
# 94  <p>I. – Après le troisième alinéa de l'article...
# 95  <p>À la première phrase de l'alinéa 2, supprim...
# 96  <p>Après l'alinéa 39, insérer l'alinéa suivant...
# 97  <p>À la première phrase de l'alinéa 7, après l...
# 98  <p>Après l'alinéa 1, insérer l'alinéa suivant ...
# 99  <p>L'article L. 5223‑1 du code du travail est ...
#
#                                id_dossier_an auteur_groupe_acronyme  \
# 0                 choix_avenir_professionnel                   LREM
# 1   habilitation_ordonnances_dialogue_social                     LR
# 2                 choix_avenir_professionnel                   LREM
# 3   habilitation_ordonnances_dialogue_social                     LR
# 4   habilitation_ordonnances_dialogue_social                     LR
# 5                 choix_avenir_professionnel                     LR
# 6   habilitation_ordonnances_dialogue_social                     LR
# 7                 choix_avenir_professionnel                     NG
# 8                 choix_avenir_professionnel                     LR
# 9                 choix_avenir_professionnel                   LREM
# 10                choix_avenir_professionnel                     LR
# 11                choix_avenir_professionnel                   LREM
# 12  habilitation_ordonnances_dialogue_social                    LFI
# 13  habilitation_ordonnances_dialogue_social                     LC
# 14  habilitation_ordonnances_dialogue_social                     LC
# 15  evolution_logement_amenagement_numerique                   LREM
# 16  habilitation_ordonnances_dialogue_social                    LFI
# 17  evolution_logement_amenagement_numerique                     LR
# 18  evolution_logement_amenagement_numerique                     LR
# 19  evolution_logement_amenagement_numerique                     NI
# 20  evolution_logement_amenagement_numerique
# 21  evolution_logement_amenagement_numerique                   LREM
# 22  evolution_logement_amenagement_numerique                   LREM
# 23  evolution_logement_amenagement_numerique                    UAI
# 24                choix_avenir_professionnel
# 25  evolution_logement_amenagement_numerique                  MODEM
# 26  evolution_logement_amenagement_numerique                     NI
# 27  evolution_logement_amenagement_numerique                     NG
# 28                fausses_informations_lutte                     NG
# 29  evolution_logement_amenagement_numerique                    UAI
# ..                                       ...                    ...
# 70                fausses_informations_lutte                    LFI
# 71                fausses_informations_lutte                   LREM
# 72  habilitation_ordonnances_dialogue_social                     LR
# 73  habilitation_ordonnances_dialogue_social                     LR
# 74                fausses_informations_lutte                    GDR
# 75                fausses_informations_lutte                     NG
# 76  evolution_logement_amenagement_numerique
# 77  evolution_logement_amenagement_numerique                     LR
# 78  habilitation_ordonnances_dialogue_social                     LR
# 79                         loi_finances_2018                   LREM
# 80                fausses_informations_lutte                    LFI
# 81  habilitation_ordonnances_dialogue_social                    LFI
# 82                fausses_informations_lutte                    LFI
# 83                fausses_informations_lutte                    GDR
# 84                choix_avenir_professionnel
# 85  habilitation_ordonnances_dialogue_social                    LFI
# 86  evolution_logement_amenagement_numerique                     NG
# 87  habilitation_ordonnances_dialogue_social                    LFI
# 88                fausses_informations_lutte                   LREM
# 89                choix_avenir_professionnel                   LREM
# 90  habilitation_ordonnances_dialogue_social                     LR
# 91  evolution_logement_amenagement_numerique                     LR
# 92  evolution_logement_amenagement_numerique                     LR
# 93                fausses_informations_lutte                   LREM
# 94  evolution_logement_amenagement_numerique                   LREM
# 95                fausses_informations_lutte                   LREM
# 96                choix_avenir_professionnel                   LREM
# 97  evolution_logement_amenagement_numerique                   LREM
# 98  habilitation_ordonnances_dialogue_social                     NG
# 99  habilitation_ordonnances_dialogue_social                   LREM
#
#    majorite_opposition
# 0             majorité
# 1           opposition
# 2             majorité
# 3           opposition
# 4           opposition
# 5           opposition
# 6           opposition
# 7                mixte
# 8           opposition
# 9             majorité
# 10          opposition
# 11            majorité
# 12          opposition
# 13          opposition
# 14          opposition
# 15            majorité
# 16          opposition
# 17          opposition
# 18          opposition
# 19          opposition
# 20        gouvernement
# 21            majorité
# 22            majorité
# 23          opposition
# 24        gouvernement
# 25            majorité
# 26          opposition
# 27          opposition
# 28          opposition
# 29          opposition
# ..                 ...
# 70          opposition
# 71            majorité
# 72          opposition
# 73          opposition
# 74          opposition
# 75          opposition
# 76        gouvernement
# 77          opposition
# 78          opposition
# 79            majorité
# 80          opposition
# 81          opposition
# 82          opposition
# 83          opposition
# 84        gouvernement
# 85          opposition
# 86          opposition
# 87          opposition
# 88            majorité
# 89            majorité
# 90          opposition
# 91          opposition
# 92          opposition
# 93            majorité
# 94            majorité
# 95            majorité
# 96            majorité
# 97            majorité
# 98          opposition
# 99            majorité
#
# [100 rows x 16 columns]

# %%
BIGRAMS_PER_GROUPE = defaultdict(Counter)
DF = defaultdict(set)
GROUPES = set()
BIGRAMS = set()
for amd in tqdm_notebook(AMENDEMENTS):
    doc = nlp(amd['expose'])

    for sentence in doc.sents:
        tokens = [token.text.lower() for token in sentence if token.is_alpha and token.text.lower() not in STOPWORDS_SET]
        
        for gram in ngrams(2, tokens):
            for groupe in amd['groupes'].split(','):
                GROUPES.add(groupe)
                gram = tuple(gram)
                BIGRAMS_PER_GROUPE[groupe][gram] += 1
                DF[gram].add(groupe)
                BIGRAMS.add(gram)
# Out:
# HBox(children=(IntProgress(value=0, max=17109), HTML(value='')))

# %%
N = len(GROUPES)

for groupe in GROUPES:
    print(groupe)
    print(len(groupe) * '-')
    
    tfidfs = Counter()
    
    for bigram, n in BIGRAMS_PER_GROUPE[groupe].items():
        
        if BIGRAMS_SET.get(bigram) != 'theme':
            continue
        
        tfidfs[bigram] = n * math.log(N / len(DF[bigram]))
        
    for bigram, n in tfidfs.most_common(25):
        print(bigram, n)
    
    print()
# Out:
# LR
# --
# ('logements', 'individuels') 54.72088902275941
# ('haut', 'débit') 45.81453659370776
# ('espaces', 'publics') 37.32315693410402
# ('communes', 'nouvelles') 36.7368005696771
# ('communes', 'intercommunalités') 34.81904781121789
# ('commun', 'urbanisme') 34.81904781121789
# ('grandes', 'opérations') 31.671188673491425
# ('taxes', 'foncières') 31.153884883721275
# ('regroupement', 'familial') 30.23759415184712
# ('mutuelles', 'étudiantes') 25.656140492476343
# ('commune', 'nouvelle') 22.90726829685388
# ('chefs', 'entreprise') 20.94385057440562
# ('revenu', 'fiscal') 18.900548079341657
# ('réseaux', 'mobiles') 18.714973875118524
# ('zones', 'rurales') 18.389722455575665
# ('équipements', 'publics') 17.62834055382257
# ('produits', 'phytopharmaceutiques') 17.62834055382257
# ('opérations', 'aménagement') 17.477072252997885
# ('communications', 'électroniques') 16.857245584277695
# ('qualité', 'air') 16.493233173734794
# ('réserve', 'parlementaire') 15.693697533304226
# ('construction', 'habitation') 15.396905040680474
# ('relations', 'commerciales') 14.813943089213732
# ('loi', 'alur') 13.910322813610563
# ('statut', 'réfugié') 13.862943611198906
#
# LREM
# ----
# ('lutte', 'évasion') 94.40598881275588
# ('optimisation', 'fiscale') 71.39415959767436
# ('égalité', 'impôt') 50.566857781689315
# ('communications', 'électroniques') 41.88770114881124
# ('bail', 'mobilité') 33.527444730240845
# ('commerce', 'équitable') 29.627886178427463
# ('construction', 'habitation') 29.00866167084727
# ('secret', 'affaires') 27.07375805959751
# ('produits', 'phytopharmaceutiques') 23.206929336677817
# ('communes', 'nouvelles') 22.873856958478193
# ('demandeur', 'emploi') 22.476327445703593
# ('qualité', 'air') 21.990977564979723
# ('haut', 'débit') 21.990977564979723
# ('gestion', 'déchets') 21.45467619817161
# ('bilan', 'compétences') 21.074686833105567
# ('agressions', 'sexuelles') 20.94385057440562
# ('relations', 'commerciales') 20.94385057440562
# ('demandeur', 'asile') 19.636632515650458
# ('loi', 'alur') 19.617121916630282
# ('fonds', 'péréquation') 19.408121055678468
# ('exploitation', 'commerciale') 19.408121055678468
# ('personnes', 'vulnérables') 18.900548079341657
# ('liberté', 'entreprendre') 18.389722455575665
# ('matières', 'premières') 18.021826694558577
# ('protéines', 'végétales') 18.021826694558577
#
# UAI
# ---
# ('communications', 'électroniques') 10.216512475319814
# ('haut', 'débit') 9.162907318741551
# ('zones', 'rurales') 6.640733108957879
# ('partis', 'groupements') 6.420148990897183
# ('loi', 'transition') 4.993449215142253
# ('produits', 'phytopharmaceutiques') 4.686014577598405
# ('monuments', 'historiques') 4.597430613893916
# ('commerce', 'équitable') 4.597430613893916
# ('précarité', 'énergétique') 3.793440372341566
# ('produits', 'alimentaires') 3.6876180480239222
# ('valeurs', 'locatives') 3.5757793663619353
# ('taxe', 'séjour') 3.5702968210273562
# ('droits', 'femmes') 3.566749439387324
# ('communes', 'nouvelles') 3.4657359027997265
# ('réseaux', 'mobiles') 3.4657359027997265
# ('miels', 'originaires') 3.4657359027997265
# ('contrat', 'professionnalisation') 3.2100744954485916
# ('permis', 'construire') 3.124009718398937
# ('mélange', 'miels') 3.0649537425959443
# ('relations', 'commerciales') 3.0649537425959443
# ('rénovation', 'énergétique') 2.900866167084727
# ('local', 'urbanisme') 2.853399551509859
# ('politique', 'logement') 2.853399551509859
# ('commune', 'nouvelle') 2.7488721956224653
# ('fruits', 'légumes') 2.5541281188299534
#
# NI
# --
# ('fausses', 'informations') 5.132301680226824
# ('liberté', 'expression') 4.686014577598405
# ('regroupement', 'familial') 4.5814536593707755
# ('libertés', 'fondamentales') 3.5757793663619353
# ('développement', 'sport') 3.5757793663619353
# ('droit', 'propriété') 3.0649537425959443
# ('accès', 'internet') 3.0649537425959443
# ('produits', 'phytopharmaceutiques') 2.900866167084727
# ('produits', 'biologiques') 2.853399551509859
# ('exploitation', 'commerciale') 2.772588722239781
# ('loi', 'transition') 2.4967246075711267
# ('exercice', 'mandat') 2.1400496636323942
# ('informatique', 'libertés') 2.1400496636323942
# ('produits', 'alimentaires') 2.107210313156527
# ('produits', 'locaux') 2.043302495063963
# ('information', 'consommateurs') 2.043302495063963
# ('permis', 'construire') 2.008291961827888
# ('demandeur', 'asile') 2.008291961827888
# ('rénovation', 'énergétique') 1.7851484105136781
# ('plateformes', 'ligne') 1.783374719693662
# ('agriculture', 'française') 1.783374719693662
# ('transfert', 'compétence') 1.5620048591994684
# ('forces', 'armées') 1.5620048591994684
# ('téléphonie', 'mobile') 1.5324768712979722
# ('recours', 'abusifs') 1.5324768712979722
#
# LFI
# ---
# ('encadrement', 'loyers') 22.873856958478193
# ('libertés', 'fondamentales') 14.303117465447741
# ('droits', 'libertés') 11.056923262100705
# ('violences', 'conjugales') 7.846848766652113
# ('harcèlement', 'moral') 6.931471805599453
# ('matières', 'premières') 6.238324625039508
# ('harcèlement', 'sexuel') 6.129907485191889
# ('victimes', 'violences') 6.063474046958451
# ('titre', 'séjour') 5.900188876838276
# ('peine', 'complémentaire') 4.993449215142253
# ('parc', 'locatif') 4.993449215142253
# ('droits', 'fondamentaux') 4.9091581289126145
# ('bail', 'mobilité') 4.636774271203521
# ('communications', 'électroniques') 4.597430613893916
# ('secret', 'affaires') 4.086604990127926
# ('fausses', 'informations') 4.016583923655776
# ('éducation', 'nationale') 3.9234243833260565
# ('droits', 'femmes') 3.9234243833260565
# ('grandes', 'opérations') 3.5757793663619353
# ('demandes', 'asile') 3.566749439387324
# ('émissions', 'gaz') 3.124009718398937
# ('fruits', 'légumes') 3.0649537425959443
# ('situation', 'handicap') 2.950094438419138
# ('liberté', 'expression') 2.900866167084727
# ('droit', 'information') 2.900866167084727
#
# GDR
# ---
# ('paradis', 'fiscaux') 14.303117465447741
# ('statut', 'réfugié') 6.238324625039508
# ('miels', 'originaires') 6.238324625039508
# ('marchands', 'sommeil') 5.355445231541035
# ('mélange', 'miels') 4.086604990127926
# ('perte', 'autonomie') 4.016583923655776
# ('taxe', 'séjour') 3.5702968210273562
# ('résidences', 'secondaires') 3.4657359027997265
# ('construction', 'habitation') 3.124009718398937
# ('valeurs', 'locatives') 3.0649537425959443
# ('gestion', 'logements') 2.772588722239781
# ('encadrement', 'loyers') 2.772588722239781
# ('habitat', 'indigne') 2.6777226157705174
# ('relations', 'commerciales') 2.5541281188299534
# ('demandes', 'asile') 2.4967246075711267
# ('égalité', 'impôt') 2.4079456086518722
# ('qualité', 'service') 2.2314355131420975
# ('nombre', 'logements') 2.1400496636323942
# ('accompagnement', 'social') 2.043302495063963
# ('qualité', 'origine') 2.043302495063963
# ('lutte', 'habitat') 1.7851484105136781
# ('olympiques', 'paralympiques') 1.7851484105136781
# ('loi', 'alur') 1.783374719693662
# ('opérations', 'aménagement') 1.783374719693662
# ('téléphonie', 'mobile') 1.5324768712979722
#
# MODEM
# -----
# ('bilan', 'compétences') 17.409523905608946
# ('droits', 'femmes') 9.986898430284507
# ('contrats', 'professionnalisation') 7.846848766652113
# ('contrat', 'professionnalisation') 7.846848766652113
# ('demandeur', 'asile') 6.694306539426293
# ('revenu', 'fiscal') 6.129907485191889
# ('construction', 'habitation') 5.801732334169454
# ('mixité', 'sociale') 5.801732334169454
# ('fonds', 'chaleur') 5.545177444479562
# ('situation', 'irrégulière') 5.355445231541035
# ('réserve', 'parlementaire') 4.993449215142253
# ('évolution', 'professionnelle') 4.993449215142253
# ('permis', 'construire') 4.9091581289126145
# ('statut', 'réfugié') 4.852030263919617
# ('grandes', 'surfaces') 4.636774271203521
# ('accompagnement', 'social') 4.597430613893916
# ('précarité', 'alimentaire') 4.597430613893916
# ('taxe', 'séjour') 4.462871026284195
# ('transition', 'professionnelle') 4.2800993272647885
# ('harcèlement', 'moral') 4.1588830833596715
# ('avenir', 'professionnel') 4.086604990127926
# ('travailleurs', 'handicapés') 4.016583923655776
# ('mutuelles', 'étudiantes') 3.6651629274966204
# ('titre', 'séjour') 3.582257532366096
# ('harcèlement', 'sexuel') 3.5757793663619353
#
# LC
# --
# ('métiers', 'artisanat') 11.911779514364017
# ('chefs', 'entreprise') 10.216512475319814
# ('énergie', 'renouvelable') 7.1515587327238705
# ('impôt', 'fortune') 4.636774271203521
# ('climat', 'énergie') 3.5702968210273562
# ('énergies', 'fossiles') 3.566749439387324
